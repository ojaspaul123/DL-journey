# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaspaul123/DL-journey/blob/main/CNN/Pretrained_models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input,decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
# Out:
# ...
# 102967424/102967424 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
img_path = '/content/bun.jpg'
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)
#

# %%
pred = model.predict(x)
print('Predicted:', decode_predictions(pred, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# Predicted: [('n07684084', 'French_loaf', np.float32(0.6411752)), ('n07693725', 'bagel', np.float32(0.30207646)), ('n07697313', 'cheeseburger', np.float32(0.031663608))]

# %%
img_path = '/content/chair.jpg'
img = image.load_img(img_path, target_size=(224, 224))
y = image.img_to_array(img)
y = np.expand_dims(x, axis=0)
y = preprocess_input(x)

# %%
pred = model.predict(y)
print('Predicted:', decode_predictions(pred, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Predicted: [('n07693725', 'bagel', np.float32(0.74867576)), ('n07860988', 'dough', np.float32(0.078696564)), ('n07753113', 'fig', np.float32(0.057646565))]
