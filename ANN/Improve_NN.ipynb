# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaspaul123/DL-journey/blob/main/ANN/Improve_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **How to improve the performance of Neural Network?**
#
# 1. Fine tuning in NN Hyperparameters.
# a. Hidden Layers.
# b. Neurons Per Layers.
# c. Learning Rate -> GD.
# d. Batch Size.
# e. Activation Function.
# f. Epochs.
#
# 2. By solving problems:
# a. Vanishing and Exploding Gradient.
# i. Weight Initial.
# ii. Activation Function.
# iii. Batch Norms.
# iv. Gradient Clipping.
# b. Not Enough Data.
# i. Transfer Learning.
# ii. Unsupervisied Learning.
# c. Slow Training.
# i. Optimizer.
# ii. Learning Rate Scheduler.
# d. Overfitting.
# i. L1 and L2 Regularization.
# ii. Dropouts.
