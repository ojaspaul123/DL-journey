# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaspaul123/DL-journey/blob/main/DL_Project/Next%20Word%20Predictor/lstm_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
faqs = """About the Program
What is the course fee for the Full Stack Web Development Mentorship Program (FSWD 2024)?
The course follows a monthly subscription model where you have to make monthly payments of Rs 999/month.
What is the total duration of the course?
The total duration of the course is 6 months. So the total course fee becomes 999*6 = Rs 5994(approx.)
What is the syllabus of the mentorship program?
We will be covering the following modules:
HTML, CSS & JavaScript Fundamentals
Frontend Frameworks (React)
Backend Development (Node.js & Express)
Databases (SQL & MongoDB)
REST APIs & Authentication
Deployment & DevOps Basics
Case studies
You can check the detailed syllabus here - https://learnwith.campusx.in/courses/CampusX-FullStack-Web-Dev-Mentorship-Program
Will Mobile App Development be a part of this program?
No, Mobile App Development (iOS/Android) is not a part of this program's curriculum.
What if I miss a live session? Will I get a recording of the session?
Yes, all our sessions are recorded, so even if you miss a session you can go back and watch the recording.
Where can I find the class schedule?
Checkout this google sheet to see month by month time table of the course - https://docs.google.com/spreadsheets/d/example-schedule-link/edit?usp=sharing.
What is the time duration of all the live sessions?
Roughly, all the sessions last 2 hours.
What is the language spoken by the instructor during the sessions?
Hinglish
How will I be informed about the upcoming class?
You will get a mail from our side before every paid session once you become a paid user.
Can I do this course if I am from a non-tech background?
Yes, absolutely.
I am late, can I join the program in the middle?
Absolutely, you can join the program anytime.
If I join/pay in the middle, will I be able to see all the past lectures?
Yes, once you make the payment you will be able to see all the past content in your dashboard.
Where do I have to submit the task?
You don't have to submit the task. We will provide you with the solutions, you have to self evaluate the task yourself.
Will we do case studies in the program?
Yes.
Where can we contact you?
You can mail us at support.campusx@gmail.com

Payment/Registration related questions
Where do we have to make our payments? Your YouTube channel or website?
You have to make all your monthly payments on our website. Here is the link for our website - https://learnwith.campusx.in/
Can we pay the entire amount of Rs 5994 all at once?
Unfortunately no, the program follows a monthly subscription model.
What is the validity of monthly subscription? Suppose if I pay on 10th Mar, then do I have to pay again on 1st Apr or 10th Apr?
10th Apr. The validity period is 30 days from the day you make the payment. So essentially you can join anytime, you don't have to wait for a month to end.
What if I don't like the course after making the payment. What is the refund policy?
You get a 7 days refund period from the day you have made the payment.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at support.campusx@gmail.com

Post registration queries
Till when can I view the paid videos on the website?
This one is tricky, so read carefully. You can watch the videos till your subscription is valid. Suppose you have purchased subscription on 10th Mar, you will be able to watch all the past paid sessions in the period of 10th Mar to 9th Apr. But after 9th Apr you will have to purchase the subscription again.
But once the course is over and you have paid us Rs 5994 (or 6 installments of Rs 999) you will be able to watch the paid sessions till Aug 2025.
Why lifetime validity is not provided?
Because of the low course fee.
Where can I reach out in case of a doubt after the session?
You will have to fill a google form provided in your dashboard and our team will contact you for a 1 on 1 doubt clearance session.
If I join the program late, can I still ask past week doubts?
Yes, just select past week doubt in the doubt clearance google form.
I am living outside India and I am not able to make the payment on the website, what should I do?
You have to contact us by sending a mail at support.campusx@gmail.com

Certificate and Placement Assistance related queries
What is the criteria to get the certificate?
There are 2 criterias:
You have to pay the entire fee of Rs 5994
You have to attempt all the course assessments.
I am joining late. How can I pay payment of the earlier months?
You will get a link to pay fee of earlier months in your dashboard once you pay for the current month.
I have read that Placement assistance is a part of this program. What comes under Placement assistance?
This is to clarify that Placement assistance does not mean Placement guarantee. So we don't guarantee you any jobs or for that matter even interview calls. So if you are planning to join this course just for placements, I am afraid you will be disappointed. Here is what comes under placement assistance:
Portfolio Building sessions
Soft skill sessions
Sessions with industry mentors
Discussion on Job hunting strategies
"""

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts([faqs])

# %%
len(tokenizer.word_index)
# Out:
# 291

# %%
input_sequences = []
for sentence in faqs.split('\n'):
  tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]

  for i in range(1,len(tokenized_sentence)):
    input_sequences.append(tokenized_sentence[:i+1])

# %%
input_sequences
# Out:
# [[92, 1],
#  [92, 1, 13],
#  [11, 5],
#  [11, 5, 1],
#  [11, 5, 1, 12],
#  [11, 5, 1, 12, 42],
#  [11, 5, 1, 12, 42, 24],
#  [11, 5, 1, 12, 42, 24, 1],
#  [11, 5, 1, 12, 42, 24, 1, 145],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146, 93],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146, 93, 53],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146, 93, 53, 67],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146, 93, 53, 67, 13],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146, 93, 53, 67, 13, 147],
#  [11, 5, 1, 12, 42, 24, 1, 145, 146, 93, 53, 67, 13, 147, 148],
#  [1, 12],
#  [1, 12, 94],
#  [1, 12, 94, 6],
#  [1, 12, 94, 6, 43],
#  [1, 12, 94, 6, 43, 28],
#  [1, 12, 94, 6, 43, 28, 95],
#  [1, 12, 94, 6, 43, 28, 95, 29],
#  [1, 12, 94, 6, 43, 28, 95, 29, 2],
#  [1, 12, 94, 6, 43, 28, 95, 29, 2, 8],
#  [1, 12, 94, 6, 43, 28, 95, 29, 2, 8, 4],
#  [1, 12, 94, 6, 43, 28, 95, 29, 2, 8, 4, 25],
#  [1, 12, 94, 6, 43, 28, 95, 29, 2, 8, 4, 25, 43],
#  [1, 12, 94, 6, 43, 28, 95, 29, 2, 8, 4, 25, 43, 68],
# ...

# %%
max_len = max([len(x) for x in input_sequences])

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
padded_input_sequences = pad_sequences(input_sequences, maxlen = max_len, padding='pre')

# %%
padded_input_sequences
# Out:
# array([[  0,   0,   0, ...,   0,  92,   1],
#        [  0,   0,   0, ...,  92,   1,  13],
#        [  0,   0,   0, ...,   0,  11,   5],
#        ...,
#        [  0,   0,   0, ..., 288,  17, 289],
#        [  0,   0,   0, ...,  17, 289, 290],
#        [  0,   0,   0, ..., 289, 290, 291]], dtype=int32)

# %%
X = padded_input_sequences[:,:-1]

# %%
y = padded_input_sequences[:,-1]

# %%
y.shape
# Out:
# (867,)

# %%
X.shape
# Out:
# (867, 56)

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'you': 2,
#  'i': 3,
#  'to': 4,
#  'is': 5,
#  'a': 6,
#  'of': 7,
#  'have': 8,
#  'will': 9,
#  'can': 10,
#  'what': 11,
#  'course': 12,
#  'program': 13,
#  'in': 14,
#  'all': 15,
#  'sessions': 16,
#  'on': 17,
#  'be': 18,
#  'this': 19,
#  'if': 20,
#  'am': 21,
#  'pay': 22,
#  'payment': 23,
#  'for': 24,
#  'make': 25,
#  'we': 26,
#  'do': 27,
#  'subscription': 28,
#  'where': 29,
#  'rs': 30,
#  'so': 31,
#  'campusx': 32,
#  'session': 33,
#  'our': 34,
#  'and': 35,
#  'paid': 36,
#  'join': 37,
#  'able': 38,
#  'your': 39,
#  'website': 40,
#  'placement': 41,
#  'fee': 42,
#  'monthly': 43,
#  'month': 44,
#  'not': 45,
#  'get': 46,
#  'yes': 47,
#  'once': 48,
#  'past': 49,
#  '10th': 50,
#  'apr': 51,
#  'assistance': 52,
#  'development': 53,
#  '5994': 54,
#  'watch': 55,
#  'google': 56,
#  'by': 57,
#  'com': 58,
#  'mail': 59,
#  'from': 60,
#  "don't": 61,
#  'contact': 62,
#  'us': 63,
#  'at': 64,
#  'or': 65,
#  'doubt': 66,
# ...

# %%
from tensorflow.keras.utils import to_categorical
y = to_categorical(y,num_classes=292)

# %%
y.shape
# Out:
# (867, 292)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.layers import Input

# %%
model = Sequential()
model.add(Input(shape=(56,)))
model.add(Embedding(292, 100))
model.add(LSTM(150))
model.add(Dense(292, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 56, 100)        │        29,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 150)            │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 292)            │        44,092 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 223,892 (874.58 KB)
#  Trainable params: 223,892 (874.58 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
X
# Out:
# array([[  0,   0,   0, ...,   0,   0,  92],
#        [  0,   0,   0, ...,   0,  92,   1],
#        [  0,   0,   0, ...,   0,   0,  11],
#        ...,
#        [  0,   0,   0, ...,   0, 288,  17],
#        [  0,   0,   0, ..., 288,  17, 289],
#        [  0,   0,   0, ...,  17, 289, 290]], dtype=int32)

# %%
model.fit(X,y,epochs=100)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.0681 - loss: 5.4502
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - accuracy: 0.0784 - loss: 5.1176
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.0784 - loss: 5.0385
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.0784 - loss: 4.9936
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.0715 - loss: 4.9314
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.0796 - loss: 4.8473
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.0980 - loss: 4.7189
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1130 - loss: 4.5578
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1407 - loss: 4.3454
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.1499 - loss: 4.1308
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1869 - loss: 3.9119
# ...

# %%
import numpy as np

# %%
import time
text = "You should be "

for i in range(10):
  # tokenize
  token_text = tokenizer.texts_to_sequences([text])[0]
  # padding
  padded_token_text = pad_sequences([token_text], maxlen=56, padding='pre')
  # predict
  pos = np.argmax(model.predict(padded_token_text))

  for word,index in tokenizer.word_index.items():
    if index == pos:
      text = text + " " + word
      print(text)
      time.sleep(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# You should be  able
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# You should be  able to
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# You should be  able to see
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# You should be  able to see all
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# You should be  able to see all the
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# You should be  able to see all the past
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# You should be  able to see all the past content
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# You should be  able to see all the past content in
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# You should be  able to see all the past content in your
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# You should be  able to see all the past content in your dashboard
