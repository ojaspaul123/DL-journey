# %% [markdown]
# <a href="https://colab.research.google.com/github/ojaspaul123/DL-journey/blob/main/DL_Project/Image_Classification/cagvsdog_with_data_Augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d salader/dogsvscats
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.2), please consider upgrading to the latest version (2.2.2)
# Dataset URL: https://www.kaggle.com/datasets/salader/dogsvscats
# License(s): unknown
# Downloading dogsvscats.zip to /content
# 100% 1.06G/1.06G [00:53<00:00, 21.5MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/dogsvscats.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
batch_size = 16

train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/train',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        '/content/test',
        target_size=(150, 150),
        batch_size=32,
        class_mode='binary')
# Out:
# Found 20000 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=2000 // batch_size,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=800 // batch_size
)
# Out:
# Epoch 1/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 36s 249ms/step - accuracy: 0.5540 - loss: 0.6904 - val_accuracy: 0.6381 - val_loss: 0.6693
# Epoch 2/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 40s 324ms/step - accuracy: 0.6245 - loss: 0.6548 - val_accuracy: 0.6294 - val_loss: 0.6244
# Epoch 3/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 31s 247ms/step - accuracy: 0.6610 - loss: 0.6149 - val_accuracy: 0.6319 - val_loss: 0.6254
# Epoch 4/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 30s 240ms/step - accuracy: 0.6823 - loss: 0.6015 - val_accuracy: 0.6925 - val_loss: 0.5603
# Epoch 5/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 224ms/step - accuracy: 0.7082 - loss: 0.5766 - val_accuracy: 0.7569 - val_loss: 0.5011
# Epoch 6/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 69s 239ms/step - accuracy: 0.7053 - loss: 0.5703 - val_accuracy: 0.7125 - val_loss: 0.5721
# Epoch 7/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 41s 329ms/step - accuracy: 0.7178 - loss: 0.5566 - val_accuracy: 0.7437 - val_loss: 0.4979
# Epoch 8/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 30s 239ms/step - accuracy: 0.7243 - loss: 0.5473 - val_accuracy: 0.7194 - val_loss: 0.5315
# Epoch 9/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 29s 236ms/step - accuracy: 0.7350 - loss: 0.5328 - val_accuracy: 0.7606 - val_loss: 0.4969
# Epoch 10/10
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 28s 229ms/step - accuracy: 0.7480 - loss: 0.5191 - val_accuracy: 0.7006 - val_loss: 0.6040

# %%
from google.colab import drive
drive.mount('/content/drive')
